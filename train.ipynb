# %%
# !git clone https://github.com/ultralytics/yolov5 #download Yolov5 into your repo 
# %cd yolov5
# !pip install -r requirements.txt #install All the requirements
import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.9.0+cu111 (Tesla K80)

# %%
# !cp -r /content/drive/MyDrive/mushroom-data /content/yolov5

# %%
# %cat /content/yolov5/data/mushroom_data.yaml
# Out:
# train: ./mushroom-data/images/train/
# val: ./mushroom-data/images/val/
# test: ./mushroom-data/images/test/
#
# # number of classes
# nc: 3
#
# # class names
# names: ["edible", "inedible", "poisonous"]

# %%
# !python train.py --img 640 --batch 32 --epochs 100 --data ./data/mushroom_data.yaml --weights yolov5s.pt --name MushroomModel --cache
# Out:
# ...
# train: weights=yolov5s.pt, cfg=, data=./data/mushroom_data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=100, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=MushroomModel, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-23-ga18b0c3 torch 1.9.0+cu111 CUDA:0 (Tesla K80, 11441.1875MB)
#
# ...

# %%
# !python detect.py --conf 0.4 --weights /content/yolov5/runs/train/MushroomModel/weights/best.pt --source /content/yolov5/test-poisonous.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/MushroomModel/weights/best.pt'], source=/content/yolov5/test-poisonous.jpg, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-23-ga18b0c3 torch 1.9.0+cu111 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# Model Summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/yolov5/test-poisonous.jpg: 512x640 1 poisonous, Done. (0.033s)
# Speed: 0.6ms pre-process, 33.3ms inference, 2.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5
